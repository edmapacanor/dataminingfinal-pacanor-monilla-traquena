# %% [markdown]
# # Speedtest Data of Philippines - Datasets from Ookla, GADM Maps and NTC

# %% [markdown]
# ### Import libraries to be used for this project: numpy, pandas and geopandas

# %%
from datetime import datetime

import geopandas as gp
import pandas as pd
import numpy as np
import sweetviz as sv

# %% [markdown]
# ### Load the Philippine Boundaries from GADM.org as a GeoDataFrame (DataFrame with geometry column). For this project, we are going to use the Shapefile with Provinces Layer. We checked the DataFrame for null values and found no null values on the NAME_1 and geometry columns which is going to be used to be merged later with the Ookla data

# %%
pinas = gp.GeoDataFrame.from_file("gadm36_PHL_shp.zip", layer="gadm36_PHL_1")
pinas
# Out:
#    GID_0       NAME_0     GID_1               NAME_1 VARNAME_1 NL_NAME_1  \
# 0    PHL  Philippines   PHL.1_1                 Abra      None      None
# 1    PHL  Philippines   PHL.2_1     Agusan del Norte      None      None
# 2    PHL  Philippines   PHL.3_1       Agusan del Sur      None      None
# 3    PHL  Philippines   PHL.4_1                Aklan      None      None
# 4    PHL  Philippines   PHL.5_1                Albay      None      None
# ..   ...          ...       ...                  ...       ...       ...
# 76   PHL  Philippines  PHL.77_1            Tawi-Tawi      None      None
# 77   PHL  Philippines  PHL.78_1             Zambales      None      None
# 78   PHL  Philippines  PHL.79_1  Zamboanga del Norte      None      None
# 79   PHL  Philippines  PHL.80_1    Zamboanga del Sur      None      None
# 80   PHL  Philippines  PHL.81_1    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1  CC_1 HASC_1  \
# 0   Lalawigan|Probinsya  Province  1401  PH.AB
# 1   Lalawigan|Probinsya  Province  1602  PH.AN
# 2   Lalawigan|Probinsya  Province  1603  PH.AS
# 3   Lalawigan|Probinsya  Province   604  PH.AK
# 4   Lalawigan|Probinsya  Province   505  PH.AL
# ..                  ...       ...   ...    ...
# 76  Lalawigan|Probinsya  Province  1570  PH.TT
# 77  Lalawigan|Probinsya  Province   155  PH.PN
# 78  Lalawigan|Probinsya  Province   972  PH.ZN
# 79  Lalawigan|Probinsya  Province   973  PH.ZS
# 80  Lalawigan|Probinsya  Province   983  PH.ZY
#
#                                              geometry
# 0   POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1   POLYGON ((125.44627 8.66631, 125.44199 8.66333...
# 2   POLYGON ((125.90923 7.99845, 125.90176 7.99794...
# 3   MULTIPOLYGON (((122.42083 11.63194, 122.42000 ...
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# ..                                                ...
# 76  MULTIPOLYGON (((119.46694 4.58694, 119.46639 4...
# 77  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...
# 78  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...
# 79  MULTIPOLYGON (((122.29816 6.87506, 122.29816 6...
# 80  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
# [81 rows x 11 columns]

# %%
pinas.isnull().sum()
# Out:
# GID_0         0
# NAME_0        0
# GID_1         0
# NAME_1        0
# VARNAME_1    78
# NL_NAME_1    81
# TYPE_1        0
# ENGTYPE_1     0
# CC_1          0
# HASC_1        0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Load the data from Ookla for Fixed Broadband. For this project, we are going to use a single file from a quarter of the year 2019 for the purpose of simulating the process. We also checked for nulls in this DataFrame and found no nulls.

# %%
q3m2019 = gp.GeoDataFrame.from_file("2019mobile_q3.zip")
print(q3m2019.head())
print(q3m2019.shape)
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  2103210323002023       30274        8090          32      4        3
# 1  0231301312310233       48685       14071          25      1        1
# 2  1202322333323102       28471       13538          44      8        8
# 3  1200213310123120       66861        9857          18      2        2
# 4  1233302122120210       13794        6350          32      6        6
#
#                                             geometry
# 0  POLYGON ((-60.11169 -34.06631, -60.10620 -34.0...
# 1  POLYGON ((-96.04797 30.26381, -96.04248 30.263...
# 2  POLYGON ((13.95264 41.00892, 13.95813 41.00892...
# 3  POLYGON ((10.78857 59.46183, 10.79407 59.46183...
# 4  POLYGON ((80.34302 7.25350, 80.34851 7.25350, ...
# (4012185, 7)

# %%
q3m2019.isnull().sum()
# Out:
# quadkey       0
# avg_d_kbps    0
# avg_u_kbps    0
# avg_lat_ms    0
# tests         0
# devices       0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Join the Ookla Datasets with Philippine Boundaries to get the geometries of Philippine Provinces with at least 1 tile.

# %%
ph_q3m2019 = gp.sjoin(pinas[['NAME_1','geometry']], q3m2019, how="inner", predicate='intersects')
print(ph_q3m2019.head())
print(ph_q3m2019.shape)
# Out:
#   NAME_1                                           geometry  index_right  \
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1254193
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      3222390
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      3091225
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...       324621
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...       259519
#
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices
# 0  1323012311232030        1015        3360          57      1        1
# 0  1323012311232012        1285        1729          40      1        1
# 0  1323012311233010       11719        8065          63      2        2
# 0  1323012313002220       13580        5679          40      3        3
# 0  1323012313030133        1594         723          64      4        3
# (27780, 9)

# %%
ph_q3m2019.isnull().sum()
# Out:
# NAME_1         0
# geometry       0
# index_right    0
# quadkey        0
# avg_d_kbps     0
# avg_u_kbps     0
# avg_lat_ms     0
# tests          0
# devices        0
# dtype: int64

# %% [markdown]
# ### Next step would be to merge the data with the list of provinces and regions to in order to match a certain province to its corresponding region.

# %%
phregions = pd.read_csv("provreg.csv")
phregions
# Out:
#                  NAME_1       Region
# 0                  Abra          CAR
# 1      Agusan del Norte  Region XIII
# 2        Agusan del Sur  Region XIII
# 3                 Aklan    Region VI
# 4                 Albay     Region V
# ..                  ...          ...
# 77             Zambales   Region III
# 78  Zamboanga del Norte    Region IX
# 79    Zamboanga del Sur    Region IX
# 80    Zamboanga Sibugay    Region IX
# 81  Metropolitan Manila          NCR
#
# [82 rows x 2 columns]

# %%
ph_q3m2019_regions = pd.merge(ph_q3m2019,phregions, on="NAME_1", how="inner")
ph_q3m2019_regions
# Out:
#                   NAME_1                                           geometry  \
# 0                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 2                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 3                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 4                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# ...                  ...                                                ...
# 27116  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 27117  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 27118  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 27119  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 27120  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
#        index_right           quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  \
# 0          1254193  1323012311232030        1015        3360          57
# 1          3222390  1323012311232012        1285        1729          40
# 2          3091225  1323012311233010       11719        8065          63
# 3           324621  1323012313002220       13580        5679          40
# 4           259519  1323012313030133        1594         723          64
# ...            ...               ...         ...         ...         ...
# 27116      1526351  1323213121231203        7389       14988          60
# 27117      2125410  1323213121231221        8626       22186          45
# 27118      2525940  1323213121230300        5866       10703          53
# 27119      2300202  1323213121231030       19638        4412          41
# 27120      2191311  1323213120200211       11404        2536          43
#
#        tests  devices     Region
# 0          1        1        CAR
# 1          1        1        CAR
# 2          2        2        CAR
# 3          3        3        CAR
# 4          4        3        CAR
# ...      ...      ...        ...
# 27116     10        3  Region IX
# 27117      2        2  Region IX
# 27118      1        1  Region IX
# 27119      1        1  Region IX
# 27120      1        1  Region IX
#
# [27121 rows x 10 columns]

# %% [markdown]
# ### We added columns to convert the average upload and download speeds from KBPS to MBPS for the purpose of data simplification.

# %%
ph_q3m2019_regions['avg_d_mbps'] = ph_q3m2019_regions['avg_d_kbps'] / 1000
ph_q3m2019_regions['avg_u_mbps'] = ph_q3m2019_regions['avg_u_kbps'] / 1000
ph_q3m2019_regions.head()
ph_q3m2019_regions.shape
# Out:
# (27121, 12)

# %% [markdown]
# ### We used groupby "Region" to further simplify the data into regions, and aggregate statistics to get the Mean of Upload Speed, Download Speeds and Latency, and the Sum of Number of Tests and Devices per Province. Using the aggregate function also drops the unnecessary columns in the process such as geometry and index columns and would only return specified columns in the expression. We then renamed the columns for proper presentation using array and rename function.

# %%
d = {'tests': 'Tests (Q3-2019)', 'devices': 'Devices (Q3-2019)', 'avg_lat_ms':'Ave Latency(ms) (Q3-2019)','avg_d_mbps':'Ave Download(Mbps) (Q3-2019)','avg_u_mbps':'Ave Upload(Mbps) (Q3-2019)'}
ph_q3m2019_regions_grp = ph_q3m2019_regions.groupby('Region').agg({'tests':'sum', 'devices':'sum','avg_lat_ms':'mean','avg_d_mbps':'mean', 'avg_u_mbps':'mean'}).rename(columns=d)
ph_q3m2019_regions_grp
# Out:
#              Tests (Q3-2019)  Devices (Q3-2019)  Ave Latency(ms) (Q3-2019)  \
# Region
# ARMM                    1386                618                  81.908397
# CAR                     4043               2250                  66.744283
# NCR                   139675              76698                  34.592169
# Region I                9926               5246                  47.005021
# Region II               5513               2917                  58.718876
# Region III             34126              18309                  49.149790
# Region IV-A            52484              27047                  45.410652
# Region IV-B             2474               1244                  52.194595
# Region IX               4230               1698                  56.905145
# Region V                5657               2943                  57.329599
# Region VI              13572               7298                  70.184953
# Region VII             30134              14411                  55.432264
# Region VIII             6094               2576                  68.782922
# Region X                8973               3623                  54.150396
# Region XI              18283               6331                  64.391078
# Region XII              4814               1850                  73.348910
# Region XIII             4827               1669                  58.278207
#
#              Ave Download(Mbps) (Q3-2019)  Ave Upload(Mbps) (Q3-2019)
# Region
# ARMM                             7.786905                    4.944305
# CAR                             10.091990                    5.588306
# NCR                             22.046411                    8.369179
# Region I                        14.591382                    7.358610
# Region II                       14.533469                    7.293994
# Region III                      14.849716                    7.477600
# Region IV-A                     14.849431                    6.981691
# Region IV-B                     12.449650                    6.204551
# Region IX                       14.540777                    7.051066
# Region V                        11.356768                    5.574856
# Region VI                       10.806860                    5.525346
# Region VII                      13.917033                    5.980352
# Region VIII                     11.802491                    5.458365
# Region X                        16.537094                    7.147792
# Region XI                       14.265083                    6.458401
# Region XII                      11.363167                    5.282796
# Region XIII                     17.294518                    7.217884

# %%
ph_q3m2019_regions_grp.to_csv("ph_q3m2019_regions_grp.csv")
ph_q3m2019_regions_grp.dtypes
# Out:
# Tests (Q3-2019)                   int64
# Devices (Q3-2019)                 int64
# Ave Latency(ms) (Q3-2019)       float64
# Ave Download(Mbps) (Q3-2019)    float64
# Ave Upload(Mbps) (Q3-2019)      float64
# dtype: object
