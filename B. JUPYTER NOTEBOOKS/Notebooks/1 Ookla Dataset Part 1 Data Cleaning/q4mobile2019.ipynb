# %% [markdown]
# # Speedtest Data of Philippines - Datasets from Ookla, GADM Maps and NTC

# %% [markdown]
# ### Import libraries to be used for this project: numpy, pandas and geopandas

# %%
from datetime import datetime

import geopandas as gp
import pandas as pd
import numpy as np
import sweetviz as sv

# %% [markdown]
# ### Load the Philippine Boundaries from GADM.org as a GeoDataFrame (DataFrame with geometry column). For this project, we are going to use the Shapefile with Provinces Layer. We checked the DataFrame for null values and found no null values on the NAME_1 and geometry columns which is going to be used to be merged later with the Ookla data

# %%
pinas = gp.GeoDataFrame.from_file("gadm36_PHL_shp.zip", layer="gadm36_PHL_1")
pinas
# Out:
#    GID_0       NAME_0     GID_1               NAME_1 VARNAME_1 NL_NAME_1  \
# 0    PHL  Philippines   PHL.1_1                 Abra      None      None
# 1    PHL  Philippines   PHL.2_1     Agusan del Norte      None      None
# 2    PHL  Philippines   PHL.3_1       Agusan del Sur      None      None
# 3    PHL  Philippines   PHL.4_1                Aklan      None      None
# 4    PHL  Philippines   PHL.5_1                Albay      None      None
# ..   ...          ...       ...                  ...       ...       ...
# 76   PHL  Philippines  PHL.77_1            Tawi-Tawi      None      None
# 77   PHL  Philippines  PHL.78_1             Zambales      None      None
# 78   PHL  Philippines  PHL.79_1  Zamboanga del Norte      None      None
# 79   PHL  Philippines  PHL.80_1    Zamboanga del Sur      None      None
# 80   PHL  Philippines  PHL.81_1    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1  CC_1 HASC_1  \
# 0   Lalawigan|Probinsya  Province  1401  PH.AB
# 1   Lalawigan|Probinsya  Province  1602  PH.AN
# 2   Lalawigan|Probinsya  Province  1603  PH.AS
# 3   Lalawigan|Probinsya  Province   604  PH.AK
# 4   Lalawigan|Probinsya  Province   505  PH.AL
# ..                  ...       ...   ...    ...
# 76  Lalawigan|Probinsya  Province  1570  PH.TT
# 77  Lalawigan|Probinsya  Province   155  PH.PN
# 78  Lalawigan|Probinsya  Province   972  PH.ZN
# 79  Lalawigan|Probinsya  Province   973  PH.ZS
# 80  Lalawigan|Probinsya  Province   983  PH.ZY
#
#                                              geometry
# 0   POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1   POLYGON ((125.44627 8.66631, 125.44199 8.66333...
# 2   POLYGON ((125.90923 7.99845, 125.90176 7.99794...
# 3   MULTIPOLYGON (((122.42083 11.63194, 122.42000 ...
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# ..                                                ...
# 76  MULTIPOLYGON (((119.46694 4.58694, 119.46639 4...
# 77  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...
# 78  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...
# 79  MULTIPOLYGON (((122.29816 6.87506, 122.29816 6...
# 80  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
# [81 rows x 11 columns]

# %%
pinas.isnull().sum()
# Out:
# GID_0         0
# NAME_0        0
# GID_1         0
# NAME_1        0
# VARNAME_1    78
# NL_NAME_1    81
# TYPE_1        0
# ENGTYPE_1     0
# CC_1          0
# HASC_1        0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Load the data from Ookla for Fixed Broadband. For this project, we are going to use a single file from a quarter of the year 2019 for the purpose of simulating the process. We also checked for nulls in this DataFrame and found no nulls.

# %%
q4m2019 = gp.GeoDataFrame.from_file("2019mobile_q4.zip")
print(q4m2019.head())
print(q4m2019.shape)
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  1231213033210310        9168        2497          50     87       38
# 1  0323002121232202       34506       18960          72     27       17
# 2  3100131213200103       17265       11726          43    265       57
# 3  2103111020030103       27042       23017          31      3        3
# 4  1221012331221022       60573       38125          25      1        1
#
#                                             geometry
# 0  POLYGON ((77.11304 28.43971, 77.11853 28.43971...
# 1  POLYGON ((-65.65430 18.32846, -65.64880 18.328...
# 2  POLYGON ((110.76965 -7.54221, 110.77515 -7.542...
# 3  POLYGON ((-47.69714 -22.67992, -47.69165 -22.6...
# 4  POLYGON ((30.62988 36.93672, 30.63538 36.93672...
# (3799244, 7)

# %%
q4m2019.isnull().sum()
# Out:
# quadkey       0
# avg_d_kbps    0
# avg_u_kbps    0
# avg_lat_ms    0
# tests         0
# devices       0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Join the Ookla Datasets with Philippine Boundaries to get the geometries of Philippine Provinces with at least 1 tile.

# %%
ph_q4m2019 = gp.sjoin(pinas[['NAME_1','geometry']], q4m2019, how="inner", predicate='intersects')
print(ph_q4m2019.head())
print(ph_q4m2019.shape)
# Out:
#   NAME_1                                           geometry  index_right  \
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1637824
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1737207
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1186305
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1717286
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1111777
#
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices
# 0  1323012313102022        4707        7858          53      1        1
# 0  1323012313002103       11582        7178          46     22       18
# 0  1323012313002100        3290        3948          48      5        3
# 0  1323012313002111       13992        7877          70      8        2
# 0  1323012313001332       11806        6032          19      1        1
# (28923, 9)

# %%
ph_q4m2019.isnull().sum()
# Out:
# NAME_1         0
# geometry       0
# index_right    0
# quadkey        0
# avg_d_kbps     0
# avg_u_kbps     0
# avg_lat_ms     0
# tests          0
# devices        0
# dtype: int64

# %% [markdown]
# ### Next step would be to merge the data with the list of provinces and regions to in order to match a certain province to its corresponding region.

# %%
phregions = pd.read_csv("provreg.csv")
phregions
# Out:
#                  NAME_1       Region
# 0                  Abra          CAR
# 1      Agusan del Norte  Region XIII
# 2        Agusan del Sur  Region XIII
# 3                 Aklan    Region VI
# 4                 Albay     Region V
# ..                  ...          ...
# 77             Zambales   Region III
# 78  Zamboanga del Norte    Region IX
# 79    Zamboanga del Sur    Region IX
# 80    Zamboanga Sibugay    Region IX
# 81  Metropolitan Manila          NCR
#
# [82 rows x 2 columns]

# %%
ph_q4m2019_regions = pd.merge(ph_q4m2019,phregions, on="NAME_1", how="inner")
ph_q4m2019_regions
# Out:
#                   NAME_1                                           geometry  \
# 0                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 2                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 3                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 4                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# ...                  ...                                                ...
# 28240  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 28241  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 28242  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 28243  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 28244  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
#        index_right           quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  \
# 0          1637824  1323012313102022        4707        7858          53
# 1          1737207  1323012313002103       11582        7178          46
# 2          1186305  1323012313002100        3290        3948          48
# 3          1717286  1323012313002111       13992        7877          70
# 4          1111777  1323012313001332       11806        6032          19
# ...            ...               ...         ...         ...         ...
# 28240      1747798  1323213121231203        3686         578         106
# 28241      3398903  1323213121323003       37347       22680          28
# 28242      3493675  1323213121230122       10423       10594          31
# 28243      3473477  1323213121301302        6330       27623          62
# 28244      3275338  1323213120200213       26725       20081          94
#
#        tests  devices     Region
# 0          1        1        CAR
# 1         22       18        CAR
# 2          5        3        CAR
# 3          8        2        CAR
# 4          1        1        CAR
# ...      ...      ...        ...
# 28240      2        1  Region IX
# 28241      1        1  Region IX
# 28242      1        1  Region IX
# 28243      1        1  Region IX
# 28244      1        1  Region IX
#
# [28245 rows x 10 columns]

# %% [markdown]
# ### We added columns to convert the average upload and download speeds from KBPS to MBPS for the purpose of data simplification.

# %%
ph_q4m2019_regions['avg_d_mbps'] = ph_q4m2019_regions['avg_d_kbps'] / 1000
ph_q4m2019_regions['avg_u_mbps'] = ph_q4m2019_regions['avg_u_kbps'] / 1000
ph_q4m2019_regions.head()
ph_q4m2019_regions.shape
# Out:
# (28245, 12)

# %% [markdown]
# ### We used groupby "Region" to further simplify the data into regions, and aggregate statistics to get the Mean of Upload Speed, Download Speeds and Latency, and the Sum of Number of Tests and Devices per Province. Using the aggregate function also drops the unnecessary columns in the process such as geometry and index columns and would only return specified columns in the expression. We then renamed the columns for proper presentation using array and rename function.

# %%
d = {'tests': 'Tests (Q4-2019)', 'devices': 'Devices (Q4-2019)', 'avg_lat_ms':'Ave Latency(ms) (Q4-2019)','avg_d_mbps':'Ave Download(Mbps) (Q4-2019)','avg_u_mbps':'Ave Upload(Mbps) (Q4-2019)'}
ph_q4m2019_regions_grp = ph_q4m2019_regions.groupby('Region').agg({'tests':'sum', 'devices':'sum','avg_lat_ms':'mean','avg_d_mbps':'mean', 'avg_u_mbps':'mean'}).rename(columns=d)
ph_q4m2019_regions_grp
# Out:
#              Tests (Q4-2019)  Devices (Q4-2019)  Ave Latency(ms) (Q4-2019)  \
# Region
# ARMM                    2013                706                  68.943709
# CAR                     4779               2766                  48.615101
# NCR                   129214              72121                  35.025286
# Region I                9902               5362                  46.726946
# Region II               4973               2687                  57.442228
# Region III             36976              19980                  47.626112
# Region IV-A            54371              28281                  46.228031
# Region IV-B             2929               1564                  47.978528
# Region IX               3861               1876                  65.468278
# Region V                6830               3487                  50.971356
# Region VI              15303               7761                  63.767805
# Region VII             27799              14314                  53.134011
# Region VIII             5173               2742                  77.641588
# Region X               10473               4047                  55.295608
# Region XI              16336               6302                  60.760432
# Region XII              4426               2092                  77.015152
# Region XIII             3715               1572                  54.307074
#
#              Ave Download(Mbps) (Q4-2019)  Ave Upload(Mbps) (Q4-2019)
# Region
# ARMM                             8.977278                    6.076411
# CAR                             12.919834                    6.868661
# NCR                             22.680549                    7.957683
# Region I                        15.308816                    7.748805
# Region II                       15.652032                    8.374384
# Region III                      16.241158                    7.947769
# Region IV-A                     15.788708                    7.270606
# Region IV-B                     12.908262                    7.375350
# Region IX                       13.582476                    7.117621
# Region V                        12.597311                    7.242243
# Region VI                       11.933834                    6.147057
# Region VII                      13.775188                    6.862487
# Region VIII                     11.616041                    6.223225
# Region X                        15.326271                    6.927008
# Region XI                       13.707459                    6.635372
# Region XII                      11.575826                    5.908230
# Region XIII                     14.661182                    7.140058

# %%
ph_q4m2019_regions_grp.to_csv("ph_q4m2019_regions_grp.csv")
ph_q4m2019_regions_grp.dtypes
# Out:
# Tests (Q4-2019)                   int64
# Devices (Q4-2019)                 int64
# Ave Latency(ms) (Q4-2019)       float64
# Ave Download(Mbps) (Q4-2019)    float64
# Ave Upload(Mbps) (Q4-2019)      float64
# dtype: object
