# %% [markdown]
# # Speedtest Data of Philippines - Datasets from Ookla, GADM Maps and NTC

# %% [markdown]
# ### Import libraries to be used for this project: numpy, pandas and geopandas

# %%
from datetime import datetime

import geopandas as gp
import pandas as pd
import numpy as np
import sweetviz as sv

# %% [markdown]
# ### Load the Philippine Boundaries from GADM.org as a GeoDataFrame (DataFrame with geometry column). For this project, we are going to use the Shapefile with Provinces Layer. We checked the DataFrame for null values and found no null values on the NAME_1 and geometry columns which is going to be used to be merged later with the Ookla data

# %%
pinas = gp.GeoDataFrame.from_file("gadm36_PHL_shp.zip", layer="gadm36_PHL_1")
pinas
# Out:
#    GID_0       NAME_0     GID_1               NAME_1 VARNAME_1 NL_NAME_1  \
# 0    PHL  Philippines   PHL.1_1                 Abra      None      None
# 1    PHL  Philippines   PHL.2_1     Agusan del Norte      None      None
# 2    PHL  Philippines   PHL.3_1       Agusan del Sur      None      None
# 3    PHL  Philippines   PHL.4_1                Aklan      None      None
# 4    PHL  Philippines   PHL.5_1                Albay      None      None
# ..   ...          ...       ...                  ...       ...       ...
# 76   PHL  Philippines  PHL.77_1            Tawi-Tawi      None      None
# 77   PHL  Philippines  PHL.78_1             Zambales      None      None
# 78   PHL  Philippines  PHL.79_1  Zamboanga del Norte      None      None
# 79   PHL  Philippines  PHL.80_1    Zamboanga del Sur      None      None
# 80   PHL  Philippines  PHL.81_1    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1  CC_1 HASC_1  \
# 0   Lalawigan|Probinsya  Province  1401  PH.AB
# 1   Lalawigan|Probinsya  Province  1602  PH.AN
# 2   Lalawigan|Probinsya  Province  1603  PH.AS
# 3   Lalawigan|Probinsya  Province   604  PH.AK
# 4   Lalawigan|Probinsya  Province   505  PH.AL
# ..                  ...       ...   ...    ...
# 76  Lalawigan|Probinsya  Province  1570  PH.TT
# 77  Lalawigan|Probinsya  Province   155  PH.PN
# 78  Lalawigan|Probinsya  Province   972  PH.ZN
# 79  Lalawigan|Probinsya  Province   973  PH.ZS
# 80  Lalawigan|Probinsya  Province   983  PH.ZY
#
#                                              geometry
# 0   POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1   POLYGON ((125.44627 8.66631, 125.44199 8.66333...
# 2   POLYGON ((125.90923 7.99845, 125.90176 7.99794...
# 3   MULTIPOLYGON (((122.42083 11.63194, 122.42000 ...
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# ..                                                ...
# 76  MULTIPOLYGON (((119.46694 4.58694, 119.46639 4...
# 77  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...
# 78  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...
# 79  MULTIPOLYGON (((122.29816 6.87506, 122.29816 6...
# 80  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
# [81 rows x 11 columns]

# %%
pinas.isnull().sum()
# Out:
# GID_0         0
# NAME_0        0
# GID_1         0
# NAME_1        0
# VARNAME_1    78
# NL_NAME_1    81
# TYPE_1        0
# ENGTYPE_1     0
# CC_1          0
# HASC_1        0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Load the data from Ookla for Fixed Broadband. For this project, we are going to use a single file from a quarter of the year 2019 for the purpose of simulating the process. We also checked for nulls in this DataFrame and found no nulls.

# %%
q2m2019 = gp.GeoDataFrame.from_file("2019mobile_q2.zip")
print(q2m2019.head())
print(q2m2019.shape)
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  1231320120100310        9132        8713          54     18       12
# 1  1321001210112203       48612        9973          36      3        3
# 2  1230220321222323       32744        6136          22     13        8
# 3  0320120321303112       34523        8544         102      4        3
# 4  1220110031123022        9767        6629          68      2        1
#
#                                             geometry
# 0  POLYGON ((80.36499 26.41155, 80.37048 26.41155...
# 1  POLYGON ((116.28479 39.85494, 116.29028 39.854...
# 2  POLYGON ((46.78528 24.85155, 46.79077 24.85155...
# 3  POLYGON ((-76.73950 34.70098, -76.73401 34.700...
# 4  POLYGON ((18.14941 40.33398, 18.15491 40.33398...
# (3340189, 7)

# %%
q1m2019.isnull().sum()
# Out:
# quadkey       0
# avg_d_kbps    0
# avg_u_kbps    0
# avg_lat_ms    0
# tests         0
# devices       0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Join the Ookla Datasets with Philippine Boundaries to get the geometries of Philippine Provinces with at least 1 tile.

# %%
ph_q2m2019 = gp.sjoin(pinas[['NAME_1','geometry']], q2m2019, how="inner", predicate='intersects')
print(ph_q2m2019.head())
print(ph_q2m2019.shape)
# Out:
#   NAME_1                                           geometry  index_right  \
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1772053
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1692899
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1126350
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      1995244
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      2618997
#
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices
# 0  1323012313010130        1050         432          42      1        1
# 0  1323012313011031        3860         950          58      2        1
# 0  1323012311232332        1133        1209          59     13        4
# 0  1323012311232021        4333        1675          33      1        1
# 0  1323012313000303        1855          16          33      1        1
# (27163, 9)

# %%
ph_q2m2019.isnull().sum()
# Out:
# NAME_1         0
# geometry       0
# index_right    0
# quadkey        0
# avg_d_kbps     0
# avg_u_kbps     0
# avg_lat_ms     0
# tests          0
# devices        0
# dtype: int64

# %% [markdown]
# ### Next step would be to merge the data with the list of provinces and regions to in order to match a certain province to its corresponding region.

# %%
phregions = pd.read_csv("provreg.csv")
phregions
# Out:
#                  NAME_1       Region
# 0                  Abra          CAR
# 1      Agusan del Norte  Region XIII
# 2        Agusan del Sur  Region XIII
# 3                 Aklan    Region VI
# 4                 Albay     Region V
# ..                  ...          ...
# 77             Zambales   Region III
# 78  Zamboanga del Norte    Region IX
# 79    Zamboanga del Sur    Region IX
# 80    Zamboanga Sibugay    Region IX
# 81  Metropolitan Manila          NCR
#
# [82 rows x 2 columns]

# %%
ph_q2m2019_regions = pd.merge(ph_q2m2019,phregions, on="NAME_1", how="inner")

# %% [markdown]
# ### We added columns to convert the average upload and download speeds from KBPS to MBPS for the purpose of data simplification.

# %%
ph_q2m2019_regions['avg_d_mbps'] = ph_q2m2019_regions['avg_d_kbps'] / 1000
ph_q2m2019_regions['avg_u_mbps'] = ph_q2m2019_regions['avg_u_kbps'] / 1000
ph_q2m2019_regions.head()
ph_q2m2019_regions.shape
# Out:
# (24389, 12)

# %% [markdown]
# ### We used groupby "Region" to further simplify the data into regions, and aggregate statistics to get the Mean of Upload Speed, Download Speeds and Latency, and the Sum of Number of Tests and Devices per Province. Using the aggregate function also drops the unnecessary columns in the process such as geometry and index columns and would only return specified columns in the expression. We then renamed the columns for proper presentation using array and rename function.

# %%
d = {'tests': 'Tests (Q2-2019)', 'devices': 'Devices (Q2-2019)', 'avg_lat_ms':'Ave Latency(ms) (Q2-2019)','avg_d_mbps':'Ave Download(Mbps) (Q2-2019)','avg_u_mbps':'Ave Upload(Mbps) (Q2-2019)'}
ph_q2m2019_regions_grp = ph_q2m2019_regions.groupby('Region').agg({'tests':'sum', 'devices':'sum','avg_lat_ms':'mean','avg_d_mbps':'mean', 'avg_u_mbps':'mean'}).rename(columns=d)
ph_q2m2019_regions_grp
# Out:
#              Tests (Q1-2019)  Devices (Q1-2019)  Ave Latency(ms) (Q1-2019)  \
# Region
# ARMM                    1295                493                  78.089362
# CAR                     3859               2048                  68.593258
# NCR                   114782              58942                  45.545124
# Region I                7871               4058                  60.132345
# Region II               4023               2062                  65.253389
# Region III             30432              16175                  57.798584
# Region IV-A            45180              22877                  55.917223
# Region IV-B             2833               1174                  64.475046
# Region IX               2527               1224                  69.071560
# Region V                5021               2388                  71.686747
# Region VI              10786               5491                  73.061910
# Region VII             22361              11135                  62.912454
# Region VIII             3694               1730                  77.277551
# Region X                5984               2580                  76.316469
# Region XI               9639               4727                  63.998222
# Region XII              2915               1331                  75.685083
# Region XIII             2839               1172                  70.690335
#
#              Ave Download(Mbps) (Q1-2019)  Ave Upload(Mbps) (Q1-2019)
# Region
# ARMM                             9.425894                    5.965306
# CAR                              9.801103                    5.639625
# NCR                             18.043558                    7.663277
# Region I                        12.059348                    6.199840
# Region II                       11.184127                    5.790260
# Region III                      13.126023                    6.716969
# Region IV-A                     12.265577                    6.333098
# Region IV-B                     10.792100                    5.329701
# Region IX                       12.498095                    6.725895
# Region V                        10.744129                    4.928772
# Region VI                       10.207312                    5.399936
# Region VII                      11.904853                    5.540847
# Region VIII                     10.371610                    5.257439
# Region X                        12.779756                    6.000936
# Region XI                       11.303055                    5.990640
# Region XII                       9.304967                    5.323258
# Region XIII                     12.226878                    5.673972

# %%
ph_q2m2019_regions_grp.to_csv("ph_q2m2019_regions_grp.csv")
ph_q2m2019_regions_grp.dtypes
# Out:
# Tests (Q1-2019)                   int64
# Devices (Q1-2019)                 int64
# Ave Latency(ms) (Q1-2019)       float64
# Ave Download(Mbps) (Q1-2019)    float64
# Ave Upload(Mbps) (Q1-2019)      float64
# dtype: object
