# %% [markdown]
# # Speedtest Data of Philippines - Datasets from Ookla, GADM Maps and NTC

# %% [markdown]
# ### Import libraries to be used for this project: numpy, pandas and geopandas

# %%
from datetime import datetime

import geopandas as gp
import pandas as pd
import numpy as np
import sweetviz as sv

# %% [markdown]
# ### Load the Philippine Boundaries from GADM.org as a GeoDataFrame (DataFrame with geometry column). For this project, we are going to use the Shapefile with Provinces Layer. We checked the DataFrame for null values and found no null values on the NAME_1 and geometry columns which is going to be used to be merged later with the Ookla data

# %%
pinas = gp.GeoDataFrame.from_file("gadm36_PHL_shp.zip", layer="gadm36_PHL_1")
pinas
# Out:
#    GID_0       NAME_0     GID_1               NAME_1 VARNAME_1 NL_NAME_1  \
# 0    PHL  Philippines   PHL.1_1                 Abra      None      None
# 1    PHL  Philippines   PHL.2_1     Agusan del Norte      None      None
# 2    PHL  Philippines   PHL.3_1       Agusan del Sur      None      None
# 3    PHL  Philippines   PHL.4_1                Aklan      None      None
# 4    PHL  Philippines   PHL.5_1                Albay      None      None
# ..   ...          ...       ...                  ...       ...       ...
# 76   PHL  Philippines  PHL.77_1            Tawi-Tawi      None      None
# 77   PHL  Philippines  PHL.78_1             Zambales      None      None
# 78   PHL  Philippines  PHL.79_1  Zamboanga del Norte      None      None
# 79   PHL  Philippines  PHL.80_1    Zamboanga del Sur      None      None
# 80   PHL  Philippines  PHL.81_1    Zamboanga Sibugay      None      None
#
#                  TYPE_1 ENGTYPE_1  CC_1 HASC_1  \
# 0   Lalawigan|Probinsya  Province  1401  PH.AB
# 1   Lalawigan|Probinsya  Province  1602  PH.AN
# 2   Lalawigan|Probinsya  Province  1603  PH.AS
# 3   Lalawigan|Probinsya  Province   604  PH.AK
# 4   Lalawigan|Probinsya  Province   505  PH.AL
# ..                  ...       ...   ...    ...
# 76  Lalawigan|Probinsya  Province  1570  PH.TT
# 77  Lalawigan|Probinsya  Province   155  PH.PN
# 78  Lalawigan|Probinsya  Province   972  PH.ZN
# 79  Lalawigan|Probinsya  Province   973  PH.ZS
# 80  Lalawigan|Probinsya  Province   983  PH.ZY
#
#                                              geometry
# 0   POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1   POLYGON ((125.44627 8.66631, 125.44199 8.66333...
# 2   POLYGON ((125.90923 7.99845, 125.90176 7.99794...
# 3   MULTIPOLYGON (((122.42083 11.63194, 122.42000 ...
# 4   MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# ..                                                ...
# 76  MULTIPOLYGON (((119.46694 4.58694, 119.46639 4...
# 77  MULTIPOLYGON (((120.08285 14.75048, 120.08222 ...
# 78  MULTIPOLYGON (((122.09467 7.53152, 122.09467 7...
# 79  MULTIPOLYGON (((122.29816 6.87506, 122.29816 6...
# 80  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
# [81 rows x 11 columns]

# %%
pinas.isnull().sum()
# Out:
# GID_0         0
# NAME_0        0
# GID_1         0
# NAME_1        0
# VARNAME_1    78
# NL_NAME_1    81
# TYPE_1        0
# ENGTYPE_1     0
# CC_1          0
# HASC_1        0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Load the data from Ookla for Fixed Broadband. For this project, we are going to use a single file from a quarter of the year 2019 for the purpose of simulating the process. We also checked for nulls in this DataFrame and found no nulls.

# %%
q1m2020 = gp.GeoDataFrame.from_file("2020mobile_q1.zip")
print(q1m2020.head())
print(q1m2020.shape)
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  1231213033100333       14457        3022          30     82       44
# 1  1233010212222232       10042        4567          48     69       38
# 2  1231213033101212        8592        2566          40    117       63
# 3  1322013333311132       23863       18425          26     31       15
# 4  3100121113312313       15880        9819          27    546      269
#
#                                             geometry
# 0  POLYGON ((77.20642 28.57970, 77.21191 28.57970...
# 1  POLYGON ((73.83911 19.97851, 73.84460 19.97851...
# 2  POLYGON ((77.22290 28.58935, 77.22839 28.58935...
# 3  POLYGON ((101.23901 16.78876, 101.24451 16.788...
# 4  POLYGON ((106.82556 -6.21155, 106.83105 -6.211...
# (3903132, 7)

# %%
q1m2020.isnull().sum()
# Out:
# quadkey       0
# avg_d_kbps    0
# avg_u_kbps    0
# avg_lat_ms    0
# tests         0
# devices       0
# geometry      0
# dtype: int64

# %% [markdown]
# ### Join the Ookla Datasets with Philippine Boundaries to get the geometries of Philippine Provinces with at least 1 tile.

# %%
ph_q1m2020 = gp.sjoin(pinas[['NAME_1','geometry']], q1m2020, how="inner", predicate='intersects')
print(ph_q1m2020.head())
print(ph_q1m2020.shape)
# Out:
#   NAME_1                                           geometry  index_right  \
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      2456784
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      2566508
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      2894252
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      2564328
# 0   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...      2358459
#
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices
# 0  1323012313003233        7759       12224          46      3        2
# 0  1323012313003322        2680        5446          28      1        1
# 0  1323012313113230       25042       23343          24      3        1
# 0  1323012313002120       21449        6780          63      9        1
# 0  1323012313000322        1377        9338          71      3        2
# (34130, 9)

# %%
ph_q1m2020.isnull().sum()
# Out:
# NAME_1         0
# geometry       0
# index_right    0
# quadkey        0
# avg_d_kbps     0
# avg_u_kbps     0
# avg_lat_ms     0
# tests          0
# devices        0
# dtype: int64

# %% [markdown]
# ### Next step would be to merge the data with the list of provinces and regions to in order to match a certain province to its corresponding region.

# %%
phregions = pd.read_csv("provreg.csv")
phregions
# Out:
#                  NAME_1       Region
# 0                  Abra          CAR
# 1      Agusan del Norte  Region XIII
# 2        Agusan del Sur  Region XIII
# 3                 Aklan    Region VI
# 4                 Albay     Region V
# ..                  ...          ...
# 77             Zambales   Region III
# 78  Zamboanga del Norte    Region IX
# 79    Zamboanga del Sur    Region IX
# 80    Zamboanga Sibugay    Region IX
# 81  Metropolitan Manila          NCR
#
# [82 rows x 2 columns]

# %%
ph_q1m2020_regions = pd.merge(ph_q1m2020,phregions, on="NAME_1", how="inner")
ph_q1m2020_regions
# Out:
#                   NAME_1                                           geometry  \
# 0                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 2                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 3                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 4                   Abra  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# ...                  ...                                                ...
# 33316  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 33317  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 33318  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 33319  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
# 33320  Zamboanga Sibugay  MULTIPOLYGON (((122.85805 7.27653, 122.85837 7...
#
#        index_right           quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  \
# 0          2456784  1323012313003233        7759       12224          46
# 1          2566508  1323012313003322        2680        5446          28
# 2          2894252  1323012313113230       25042       23343          24
# 3          2564328  1323012313002120       21449        6780          63
# 4          2358459  1323012313000322        1377        9338          71
# ...            ...               ...         ...         ...         ...
# 33316      3499047  1323213121112010         553        9641          26
# 33317       896704  1323213123013031       35236        8563          28
# 33318       988575  1323213123013012        3196         510          68
# 33319       283007  1323213121323012       22457       13019          28
# 33320      2281927  1323213123013013        8233        9929          35
#
#        tests  devices     Region
# 0          3        2        CAR
# 1          1        1        CAR
# 2          3        1        CAR
# 3          9        1        CAR
# 4          3        2        CAR
# ...      ...      ...        ...
# 33316      1        1  Region IX
# 33317      3        2  Region IX
# 33318      2        1  Region IX
# 33319      2        1  Region IX
# 33320      5        1  Region IX
#
# [33321 rows x 10 columns]

# %% [markdown]
# ### We added columns to convert the average upload and download speeds from KBPS to MBPS for the purpose of data simplification.

# %%
ph_q1m2020_regions['avg_d_mbps'] = ph_q1m2020_regions['avg_d_kbps'] / 1000
ph_q1m2020_regions['avg_u_mbps'] = ph_q1m2020_regions['avg_u_kbps'] / 1000
ph_q1m2020_regions.head()
ph_q1m2020_regions.shape
# Out:
# (33321, 12)

# %% [markdown]
# ### We used groupby "Region" to further simplify the data into regions, and aggregate statistics to get the Mean of Upload Speed, Download Speeds and Latency, and the Sum of Number of Tests and Devices per Province. Using the aggregate function also drops the unnecessary columns in the process such as geometry and index columns and would only return specified columns in the expression. We then renamed the columns for proper presentation using array and rename function.

# %%
d = {'tests': 'Tests (Q1-2020)', 'devices': 'Devices (Q1-2020)', 'avg_lat_ms':'Ave Latency(ms) (Q1-2020)','avg_d_mbps':'Ave Download(Mbps) (Q1-2020)','avg_u_mbps':'Ave Upload(Mbps) (Q1-2020)'}
ph_q1m2020_regions_grp = ph_q1m2020_regions.groupby('Region').agg({'tests':'sum', 'devices':'sum','avg_lat_ms':'mean','avg_d_mbps':'mean', 'avg_u_mbps':'mean'}).rename(columns=d)
ph_q1m2020_regions_grp
# Out:
#              Tests (Q1-2020)  Devices (Q1-2020)  Ave Latency(ms) (Q1-2020)  \
# Region
# ARMM                    3165                917                  60.174263
# CAR                     6241               2983                  51.034591
# NCR                   186271              85129                  32.774387
# Region I               13920               6130                  42.431923
# Region II               6598               3216                  42.239628
# Region III             57651              24935                  45.033558
# Region IV-A            90533              36087                  44.157556
# Region IV-B             5195               1949                  57.045894
# Region IX               4825               2175                  46.782178
# Region V               10020               4246                  53.556250
# Region VI              19851               8887                  59.163380
# Region VII             42526              17366                  47.964338
# Region VIII             9277               3900                  67.436878
# Region X               11630               4316                  47.781228
# Region XI              17519               7267                  50.468789
# Region XII              6071               2359                  59.196602
# Region XIII             4295               1822                  46.169607
#
#              Ave Download(Mbps) (Q1-2020)  Ave Upload(Mbps) (Q1-2020)
# Region
# ARMM                             8.484839                    6.126777
# CAR                             10.762159                    6.035094
# NCR                             19.723741                    6.605460
# Region I                        11.884861                    6.198092
# Region II                       13.033006                    6.630197
# Region III                      12.656666                    6.277600
# Region IV-A                     12.793386                    5.971780
# Region IV-B                     12.005827                    7.411930
# Region IX                       13.000708                    7.308969
# Region V                         9.992012                    6.436051
# Region VI                        8.757151                    5.429771
# Region VII                      10.959383                    5.934258
# Region VIII                      9.430243                    5.789842
# Region X                        12.471344                    7.116060
# Region XI                       10.909785                    6.109226
# Region XII                       9.906215                    6.200291
# Region XIII                     11.402444                    6.984493

# %%
ph_q1m2020_regions_grp.to_csv("ph_q1m2020_regions_grp.csv")
ph_q1m2020_regions_grp.dtypes
# Out:
# Tests (Q1-2020)                   int64
# Devices (Q1-2020)                 int64
# Ave Latency(ms) (Q1-2020)       float64
# Ave Download(Mbps) (Q1-2020)    float64
# Ave Upload(Mbps) (Q1-2020)      float64
# dtype: object
