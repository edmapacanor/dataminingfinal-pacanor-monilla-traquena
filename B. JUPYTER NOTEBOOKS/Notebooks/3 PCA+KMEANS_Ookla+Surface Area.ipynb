# %% [markdown]
# ## PCA (Dimensionality Reduction) + K-Means: Ookla vs Surface Area

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pylab as pl
import seaborn as sns
from sklearn import datasets
# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %% [markdown]
# # Load Cleaned Data

# %%
data = pd.read_csv("final data for clustering.csv").set_index('Region')
data
# Out:
#              Unnamed: 0  Tests (Q1-2019)  Devices (Q1-2019)  \
# Region
# ARMM                  0             1295                493
# CAR                   1             3859               2048
# NCR                   2           114782              58942
# Region I              3             7871               4058
# Region II             4             4023               2062
# Region III            5            30432              16175
# Region IV-A           6            45180              22877
# Region IV-B           7             2833               1174
# Region IX             8             2527               1224
# Region V              9             5021               2388
# Region VI            10            10786               5491
# Region VII           11            22361              11135
# Region VIII          12             3694               1730
# Region X             13             5984               2580
# Region XI            14             9639               4727
# Region XII           15             2915               1331
# Region XIII          16             2839               1172
#
#              Ave Latency(ms) (Q1-2019)  Ave Download(Mbps) (Q1-2019)  \
# Region
# ARMM                         78.089362                      9.425894
# CAR                          68.593258                      9.801103
# NCR                          45.545124                     18.043558
# Region I                     60.132345                     12.059348
# Region II                    65.253389                     11.184127
# Region III                   57.798584                     13.126023
# Region IV-A                  55.917223                     12.265577
# Region IV-B                  64.475046                     10.792100
# Region IX                    69.071560                     12.498095
# Region V                     71.686747                     10.744129
# Region VI                    73.061910                     10.207313
# Region VII                   62.912454                     11.904853
# Region VIII                  77.277551                     10.371610
# Region X                     76.316469                     12.779756
# Region XI                    63.998222                     11.303055
# Region XII                   75.685083                      9.304967
# Region XIII                  70.690335                     12.226878
#
#              Ave Upload(Mbps) (Q1-2019)  Tests (Q1-2020)  Devices (Q1-2020)  \
# Region
# ARMM                           5.965306             3165                917
# CAR                            5.639625             6241               2983
# NCR                            7.663277           186271              85129
# Region I                       6.199840            13920               6130
# Region II                      5.790260             6598               3216
# Region III                     6.716969            57651              24935
# Region IV-A                    6.333098            90533              36087
# Region IV-B                    5.329701             5195               1949
# Region IX                      6.725895             4825               2175
# Region V                       4.928772            10020               4246
# Region VI                      5.399936            19851               8887
# Region VII                     5.540847            42526              17366
# Region VIII                    5.257439             9277               3900
# Region X                       6.000936            11630               4316
# Region XI                      5.990640            17519               7267
# Region XII                     5.323258             6071               2359
# Region XIII                    5.673972             4295               1822
#
#              Ave Latency(ms) (Q1-2020)  Ave Download(Mbps) (Q1-2020)  ...  \
# Region                                                                ...
# ARMM                         60.174263                      8.484839  ...
# CAR                          51.034591                     10.762159  ...
# NCR                          32.774387                     19.723741  ...
# Region I                     42.431923                     11.884861  ...
# Region II                    42.239628                     13.033006  ...
# Region III                   45.033558                     12.656666  ...
# Region IV-A                  44.157556                     12.793386  ...
# Region IV-B                  57.045894                     12.005827  ...
# Region IX                    46.782178                     13.000708  ...
# Region V                     53.556250                      9.992012  ...
# Region VI                    59.163380                      8.757151  ...
# Region VII                   47.964338                     10.959383  ...
# Region VIII                  67.436878                      9.430243  ...
# Region X                     47.781228                     12.471344  ...
# Region XI                    50.468789                     10.909785  ...
# Region XII                   59.196602                      9.906215  ...
# Region XIII                  46.169607                     11.402444  ...
#
#              Ave Download(Mbps) (Q4-2020)  Ave Upload(Mbps) (Q4-2020)  \
# Region
# ARMM                             7.108765                    5.169553
# CAR                              8.091913                    4.459382
# NCR                             28.887553                    6.562790
# Region I                        12.259604                    4.932170
# Region II                       10.890773                    5.177189
# Region III                      14.219295                    5.146316
# Region IV-A                     14.223361                    4.909055
# Region IV-B                     10.162448                    5.668466
# Region IX                       10.746596                    6.254332
# Region V                        10.425221                    5.576936
# Region VI                       10.188891                    5.343674
# Region VII                      11.826433                    5.546191
# Region VIII                      8.579837                    5.519151
# Region X                        11.665935                    6.379092
# Region XI                       12.277664                    5.743927
# Region XII                      10.645325                    6.142450
# Region XIII                      9.576202                    5.506749
#
#              Smart 2019  Smart 2020  Globe 2019  Globe 2020  \
# Region
# ARMM                 82          88         190         258
# CAR                 493         545         253         337
# NCR                6270        6973        2561        3746
# Region I           1287        1420         691        1100
# Region II           699         822         480         773
# Region III         2914        3588        1094        1506
# Region IV-A        3566        4277        1882        2496
# Region IV-B         494         606         665         767
# Region IX           623         714         378         521
# Region V            779         950         574         738
# Region VI          1585        1934         714        1126
# Region VII         1578        1829        1036        1261
# Region VIII         648         723         435         563
# Region X            902        1025         567         801
# Region XI          1117        1199         479         705
# Region XII          459         506         422         544
# Region XIII         517         571         190         254
#
#              Total Population as of May 2020  Level of Urbanization (%)  \
# Region
# ARMM                                 4404288                       13.7
# CAR                                  1797660                       26.3
# NCR                                 13484462                      100.0
# Region I                             5301139                       12.7
# Region II                            3685744                       11.6
# Region III                          12422172                       51.6
# Region IV-A                         16195042                       59.7
# Region IV-B                          3228558                       22.3
# Region IX                            3875576                       33.9
# Region V                             6082165                       15.3
# Region VI                            7954723                       34.7
# Region VII                           8081988                       43.7
# Region VIII                          4547150                        8.7
# Region X                             5022768                       41.3
# Region XI                            5243536                       59.3
# Region XII                           4901486                       46.5
# Region XIII                          2804788                       27.5
#
#              Daily Minimum Wage (Php)  Surface Area (km^2)
# Region
# ARMM                              325             12535.79
# CAR                               350             19422.03
# NCR                               537               619.57
# Region I                          340             13012.60
# Region II                         370             28228.83
# Region III                        420             22014.63
# Region IV-A                       400             16873.31
# Region IV-B                       320             29620.90
# Region IX                         316             17056.73
# Region V                          310             18155.82
# Region VI                         395             20794.18
# Region VII                        404             15487.69
# Region VIII                       325             23251.10
# Region X                          365             20496.02
# Region XI                         396             20357.42
# Region XII                        336             22513.30
# Region XIII                       320             21478.35
#
# [17 rows x 49 columns]

# %% [markdown]
# ### Transpose data and check for descriptive statistics

# %%
data.T.describe()
# Out:
# Region          ARMM           CAR           NCR      Region I     Region II  \
# count   4.900000e+01  4.900000e+01  4.900000e+01  4.900000e+01  4.900000e+01
# mean    9.160247e+04  4.147985e+04  3.251969e+05  1.149204e+05  8.015392e+04
# std     6.289527e+05  2.566433e+05  1.921434e+06  7.565630e+05  5.260244e+05
# min     0.000000e+00  1.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# 16  1.632993 -0.492750 -0.502592  0.452998  0.294308 -0.361534 -0.547887
#
#           7         8         9   ...        31        32        33        34  \
# 0  -0.572398  1.214682 -1.288361  ... -0.585990 -0.571548  1.138921 -1.803079
# 1  -0.470912  0.101565 -0.363518  ... -0.495604 -0.450723 -0.690940 -0.408219
# 2   3.564238 -2.122337  3.275872  ...  3.570635  3.617147 -1.914215  3.045082
# 3  -0.316326 -0.946150  0.092423  ... -0.328197 -0.298460 -0.860901  0.436993
# 4  -0.459467 -0.969569  0.558696  ... -0.489265 -0.455357  0.103625  0.558421
# 5   0.607407 -0.629298  0.405860  ...  0.556517  0.558927 -0.779963  0.766852
# 6   1.155212 -0.735986  0.461384  ...  1.124944  1.045805 -0.905810  0.606777
# 7  -0.521704  0.833679  0.141548  ... -0.556058 -0.521224 -0.748241 -0.412313
# 8  -0.510603 -0.416334  0.545579  ... -0.525602 -0.502924  0.826083 -0.173779
# 9  -0.408872  0.408677 -0.676282  ... -0.428582 -0.408434 -0.478844 -0.522326
# 10 -0.180898  1.091567 -1.177772  ... -0.151705 -0.157752  0.673016 -0.757062
# 11  0.235605 -0.272359 -0.283423  ...  0.256635  0.226600 -0.284175 -0.105598
# 12 -0.425868  2.099193 -0.904422  ... -0.482729 -0.452131  1.921852 -0.869496
# 13 -0.405433 -0.294660  0.330599  ... -0.309538 -0.375589 -0.089601  0.443169
# 14 -0.260475  0.032657 -0.303565  ... -0.117949 -0.243327  0.402310 -0.129561
# 15 -0.501564  1.095613 -0.711126  ... -0.507139 -0.490255  1.865464 -0.883723
# 16 -0.527943 -0.490939 -0.103492  ... -0.530373 -0.520755 -0.178583  0.207863
#
#           35        36        37        38        39        40
# 0  -1.409733 -0.618329 -0.601137  1.466307 -1.026519 -0.662269
# 1  -0.260698 -0.577409 -0.537953  0.181083 -0.814516 -1.961291
# 2   1.318758  3.262863  3.309131 -2.123002  3.669797  1.886197
# 3   1.015814 -0.392845 -0.355071 -1.100551  0.084193 -1.096483
# 4   1.923118 -0.510774 -0.466134 -0.588327 -0.210978 -0.648302
# 5   1.304380  0.732744  0.748551 -1.300366  0.506775 -0.704774
# 6   0.322260  1.658650  1.623545 -1.094805  0.507652 -1.138764
# 7   0.474175 -0.571895 -0.549364 -0.439696 -0.368032  0.250328
# 8   0.100379 -0.555477 -0.543506  0.244906 -0.242068  1.321975
# 9   0.281125 -0.388908 -0.355884 -0.119269 -0.311368  0.082903
# 10 -1.307271 -0.160716 -0.160101  1.803907 -0.362330 -0.343773
# 11 -0.269652  0.287026  0.161948  0.248562 -0.009215  0.026665
# 12 -1.196802 -0.428432 -0.437353  1.230503 -0.709302 -0.022796
# 13 -0.176074 -0.401292 -0.435016  0.238339 -0.043824  1.550183
# 14 -0.599047 -0.186069 -0.287993  0.412368  0.088088  0.388359
# 15 -1.653653 -0.584320 -0.553868  0.249914 -0.263906  1.117324
# 16  0.132921 -0.564817 -0.559793  0.690128 -0.494448 -0.045480
#
# [17 rows x 41 columns]

# %% [markdown]
# ### Perform PCA and plot the explained variances to determine if this method can be used to reduce the features.

# %%
pca = PCA(n_components=17)
principalComponents = pca.fit_transform(ookla)

# %%
# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Save components to a DataFrame
PCA_components = pd.DataFrame(principalComponents)

# %% [markdown]
# ### The explained variance for PCA[0] or first variance can be seen as approx 70%. We are going to use this 1 dimension together with another attribute and perform Kmeans to cluster the combined data

# %% [markdown]
# ### Select the PCA feature from the previous step vs the column that corresponds to Surface Area. Make sure the both columns are scaled.

# %%
for_km = pd.DataFrame(columns = ['Ookla Data Reduced Dimension', 'Surface Area'])
for_km['Ookla Data Reduced Dimension'] = PCA_components[0]
for_km['Surface Area'] = scaled_data.iloc[:,-1]
for_km
# Out:
#     Ookla Data Reduced Dimension  Surface Area
# 0                      -5.482998     -1.006227
# 1                      -3.004956      0.076350
# 2                      17.427387     -2.879562
# 3                       1.045992     -0.931269
# 4                      -0.098454      1.460857
# 5                       4.653462      0.483930
# 6                       6.364949     -0.324331
# 7                      -1.831834      1.679702
# 8                      -0.876031     -0.295496
# 9                      -2.504216     -0.122709
# 10                     -3.400593      0.292064
# 11                      0.184997     -0.542163
# 12                     -4.931710      0.678314
# 13                     -0.448526      0.245191
# 14                     -1.366040      0.223402
# 15                     -4.450400      0.562325
# 16                     -1.281029      0.399622

# %% [markdown]
# ### Using elbow method, check for possible values of K. We used k=4 for this project.

# %%
ks = range(1, 10)
inertias = []
for k in ks:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(for_km)
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(ks, inertias, '-o', color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %% [markdown]
# ### Fit the columns to the model

# %%
model = KMeans(n_clusters = 4 )
model.fit(for_km)
model.labels_
# Out:
# array([0, 0, 1, 2, 2, 3, 3, 2, 2, 0, 0, 2, 0, 2, 2, 0, 2])

# %% [markdown]
# ### Plot the result of K-means clustering and assign cluster values

# %%
colormap = np.array(['Red', 'Blue', 'Green', 'Yellow'])
plt.figure(figsize=(8, 8), dpi=80)
for color in ['0', '1', '2', '3']:
    plt.scatter(PCA_components[0], scaled_data.iloc[:,-1], c = colormap[model.labels_], label=color)  

plt.xlabel('Ookla Data')
plt.ylabel('Surface Area')

plt.show()

# %% [markdown]
# ### Save the clustering result in a CSV.

# %%
df = pd.DataFrame(columns = ['Region', 'Cluster'])
df['Region'] = data.index
df['Cluster'] = model.labels_
df.to_csv('ookla_surfacearea_clustered')
# Out:
#          Region  Cluster
# 0          ARMM        0
# 1           CAR        0
# 2           NCR        2
# 3      Region I        3
# 4     Region II        3
# 5    Region III        1
# 6   Region IV-A        1
# 7   Region IV-B        3
# 8     Region IX        3
# 9      Region V        0
# 10    Region VI        0
# 11   Region VII        3
# 12  Region VIII        0
# 13     Region X        3
# 14    Region XI        3
# 15   Region XII        0
# 16  Region XIII        3
